# %%
import rasterio
from rasterio import rio
from rasterio.mask import mask
import geopandas as gpd
from shapely import Polygon, Point
from shapely.geometry import mapping
import numpy as np
import pandas as pd
from tqdm import tqdm
import time
import sys
import glob

# %% [markdown]
# ### Loading the NTL data

# %%
# rasterio_img = rasterio.open("./data/earth_observation_group/annual/2012/VNL_v2_npp_201204-201212_global_vcmcfg_c202101211500.average.tif")

# %% [markdown]
# ## Getting radiance value inside a polygon defined by geocoordinates

# %%
def check_polar_limit(geom_coords, north_latitude_limit, south_latitude_limit):
    for coord in geom_coords:
        if coord[1] > north_latitude_limit or coord[1] < south_latitude_limit:
            return True
    return False
    
def get_polar_regions(north_latitude_limit, south_latitude_limit, country_geometry_dict):
    polar_regions = []
    
    for country, country_geometry in country_geometry_dict.items():
        if country_geometry.geom_type == "MultiPolygon":
            for i in range(len(country_geometry.geoms)):
                geom_coords = country_geometry.geoms[i].exterior.coords[::-1]
                if check_polar_limit(geom_coords, north_latitude_limit, south_latitude_limit):
                    polar_regions.append(country)
                    break
                
        else:
            geom_coords = country_geometry.exterior.coords[::-1]
            if check_polar_limit(geom_coords, north_latitude_limit, south_latitude_limit):
                polar_regions.append(country)
                break
                
    return polar_regions
    

def get_masked_polygons(rasterio_img, country_geometry_dict):
    country_mappings = {country: mapping(country_geometry) for country, country_geometry in country_geometry_dict.items()}
    country_masked_polygons = dict()
    for country, country_geometry in tqdm(country_mappings.items()):
        out_image, _ = mask(rasterio_img, [country_geometry], crop=True)
        country_masked_polygons[country] = out_image
    
    return country_masked_polygons


## Getting radiance value inside a polygon defined by geocoordinates
def get_polygon_radiance_value(masked_region_image, polygon, no_rasterio_data):
    try:
#         # transform to GeJSON format
#         geoms = [mapping(polygon)]

#         # extract the raster values values within the polygon
#         out_image, out_transform = mask(rasterio_img, geoms, crop=True)

#         # no data values of the original raster
#         no_data=rasterio_img.nodata

#         del rasterio_img

        # extract the values of the masked array
#         data = np.squeeze()
        data = np.reshape(masked_region_image.data.tolist(), (masked_region_image.shape[1], masked_region_image.shape[2]))

        # extract the row, columns of the valid values
        row, col = np.where(data != no_rasterio_data) 
        elev = np.extract(data != no_rasterio_data, data)
        rad_sum = round(np.sum(elev), 2)
    except Exception as error:
        print("Error: {} while evaluating radiance sum.".format(error))
    return rad_sum

# %% [markdown]
# ### Radiance value sum for a country

# %%
rasterio_img = rasterio.open("./data/earth_observation_group/annual/1992/F101992.v4b.global.intercal.stable_lights.avg_vis.tif")

# %%
all_country_shapefile = gpd.read_file("./data/country_geometry/all_country/ne_10m_admin_0_countries.shp")

# extract the geometry in GeoJSON format
all_country_geometry = all_country_shapefile.geometry.values # list of shapely geometries
country_names = list(all_country_shapefile.SOV_A3)
country_geometry_dict = {country_names[i]: all_country_geometry[i] for i in range(len(all_country_geometry))}

# %%
country_name = "TUR"
country_geometry = country_geometry_dict[country_name]

# %%
# for i in range(len(country_geometry.geoms)):
#     print(check_polar_limit(country_geometry.geoms[i].exterior.coords[::-1], 75.0, -65.0))

# %%
# tmp = get_polygon_radiance_value(rasterio_img, country_geometry)
# all_countries_rad_sum_dict = dict()

# for country, country_geometry in tqdm(country_geometry_dict.items()):
#     radiance_sum = get_polygon_radiance_value(rasterio_img, country_geometry)
#     all_countries_rad_sum_dict[country] = radiance_sum

# %%
# for key in ["RUS", "CAN", "NOR", "ATA"]:
#     del country_geometry_dict[key]
# tmp = {country: mapping(country_geometry) for country, country_geometry in country_geometry_dict.items()}

# %%
print("countries before deleting polar regions: ", len(country_geometry_dict))
polar_regions = get_polar_regions(75.0, -65.0, country_geometry_dict)
polar_regions.append("KIR")
for key in polar_regions:
    del country_geometry_dict[key]
    
print("countries after deleting polar regions: ", len(country_geometry_dict))
# Out:
# countries before deleting polar regions:  209
# countries after deleting polar regions:  204

# %%
base_path = "./data/earth_observation_group/annual/"
for file in glob.glob("{}*".format(base_path)):
    year = file.split("/")[-1]
    if int(year) in np.arange(1992, 2012+1):
        for rasterio_file in glob.glob(base_path+year+"/*"):
            if rasterio_file.split("/")[-1].split(".")[-1] == "tif":
                rasterio_img = rasterio.open(rasterio_file)
                masked_polygons = get_masked_polygons(rasterio_img, country_geometry_dict)
                g_min, g_max = 10**5, -10**5

                for country in masked_polygons:
                    g_min = min(g_min, np.min(masked_polygons[country]))
                    g_max = max(g_max, np.max(masked_polygons[country]))

                print(year, g_min, g_max)

# %%
base_path = "./data/earth_observation_group/annual/"
for file in glob.glob("{}*".format(base_path)):
    year = file.split("/")[-1]
    if int(year) in np.arange(1992, 2012+1):
        for rasterio_file in glob.glob(base_path+year+"/*"):
            if rasterio_file.split("/")[-1].split(".")[-1] == "tif":
                print(rasterio_file.split("/")[-1].split(".")[0][:3])
# Out:
# F15
# F14
# F15
# F16
# F16
# F15
# F16
# F15
# F15
# F14
# F14
# F15
# F14
# F15
# F18
# F12
# F14
# F18
# F14
# F12
# F18
# F12
# F14
# F10
# F10
# F12
# F12
# F12
# F15
# F16
# F16
# F16
# F10

# %%
# np.sum(masked_polygons["TUR"])
# Out:
# 1784666.9

# %%
np.max(masked_polygons["TUR"]), np.min(masked_polygons["TUR"])
# Out:
# (63.0, 0.0)

# %%
# # dir(country_geometry)
# # north_circle_coords = []
# north_circle_coords = [(long, 75) for long in range(-180, 181)]
# north_circle_polygon = Polygon(north_circle_coords)

# %%
# rasterio_img.statistics(1)
# round(np.sum(tmp), 2)
# country_geometry.intersects(north_circle_polygon)
# north_circle_coords

# for coords in north_circle_coords:
#     print(country_geometry.contains(Point(coords)))
# tmp_point = Point((10.7522, 75.9139))
# country_geometry.contains(tmp_point)

# country_geometry.intersects(north_circle_polygon)
# Out:
# True

# %%
df = pd.read_csv("./data/earth_observation_group/annual/2014/countries_ntl_sum.csv")

# %%
df
# Out:
#     Region Code  annual_ntl_sum
# 0           IDN      1335862.40
# 1           MYS      1126525.60
# 2           CHL      1350989.60
# 3           BOL       400901.60
# 4           PER       550756.94
# ..          ...             ...
# 199         BHR       180006.28
# 200         PGA           -0.19
# 201         BJN            0.00
# 202         SER           -0.01
# 203         SCR            0.00
#
# [204 rows x 2 columns]

# %% [markdown]
# ### Debugging

# %%
regions_selected = set(pd.read_csv("regions_selected.csv", header=None)[0].values)
regions_evaluated = set(pd.read_csv("regions_evaluated.csv", header=None)[0].values)

missing_regions = regions_selected - regions_evaluated

# %%
missing_regions_rad = dict()

for country_name in tqdm(list(missing_regions)):
    country_geometry = country_geometry_dict[country_name]
    missing_regions_rad[country_name] = get_polygon_radiance_value(rasterio_img, country_geometry)
# Out:
#  20%|████████████▋                                                  | 22/109 [01:07<02:37,  1.81s/it]

# %% [markdown]
# ### Radiance value sum for a city

# %%
all_cities_shapefile = gpd.read_file("./data/country_geometry/netherlands/NLD_adm2.shp")

city_geometry_dict = {}
for city_name, polygon in zip(all_cities_shapefile["NAME_2"], all_cities_shapefile["geometry"]):
    if city_name is not None:
        city_geometry_dict[city_name.lower()] = polygon

# %%
city_name = "amsterdam"
city_geometry = city_geometry_dict[city_name]

get_polygon_radiance_value(rasterio_img, city_geometry)
# Out:
# 28709.29

# %% [markdown]
# ## GDP

# %%
gdp_df = pd.read_csv("./data/gdp/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_4901850.csv")
gdp_df["Country Name"] = gdp_df["Country Name"].str.lower()

# %%
## Returns GDP of a country in USD billions
def get_gdp(df, country_name, year):
    gdp = list(df[df["Country Name"] == country_name][str(year)])
    assert len(gdp) > 0, "Country {} does not exist in the GDP database".format(country_name)
    assert gdp is not None, "GDP value not found for {} for the year {}".format(country_name, year) 
    return round(gdp[0]//10**9, 2)

# %%
get_gdp(gdp_df, "netherlands", 2021)
# Out:
# 1012.0

# %% [markdown]
# ## GDP disaggregation

# %%
country_name = "netherlands"
city_name = "leiden"
year = 2021

# %%
country_geometry = country_geometry_dict[country_name]
city_geometry = city_geometry_dict[city_name]

# %%
country_radiance_sum = get_polygon_radiance_value(rasterio_img, country_geometry)

# %%
country_gdp = get_gdp(gdp_df, country_name, year)

city_radiance_dict = {}
city_gdp_dict = {}
for city_name, city_geometry in city_geometry_dict.items():
    city_radiance = get_polygon_radiance_value(rasterio_img, city_geometry)
    city_radiance_dict[city_name] = city_radiance
    
    city_gdp_proportion = city_radiance/country_radiance_sum
    
    city_gdp = city_gdp_proportion * country_gdp
    city_gdp_dict[city_name] = (city_gdp, round(city_gdp_proportion, 6))

# %%
sorted(city_radiance_dict.items(), key= lambda x: x[1], reverse=True)
# Out:
# [('noordoostpolder', 81878.71),
#  ('naaldwijk', 72972.73),
#  ('maasland', 72839.21),
#  ('rotterdam', 68345.0),
#  ('de lier', 55691.46),
#  ('schipluiden', 53373.51),
#  ('zevenhuizen-moerkapelle', 53181.71),
#  ('wieringermeer', 52560.44),
#  ('waddinxveen', 48920.21),
#  ("'s-gravenzande", 35864.68),
#  ('pijnacker-nootdorp', 35547.84),
#  ('berkel en rodenrijs', 33957.75),
#  ('reimerswaal', 31409.28),
#  ('haarlemmermeer', 30077.03),
#  ('emmen', 29878.89),
#  ('amsterdam', 28709.29),
#  ('monster', 28526.59),
#  ('bleiswijk', 27096.37),
#  ('maasbree', 20705.75),
#  ('steenbergen', 20192.33),
#  ('westvoorne', 18229.07),
#  ("'s-gravenhage", 17523.45),
#  ('wateringen', 17510.57),
#  ('bergschenhoek', 14434.07),
#  ('eindhoven', 13686.76),
#  ('terneuzen', 11349.78),
#  ('zaltbommel', 11167.55),
#  ('utrecht', 11114.29),
#  ('moerdijk', 9738.2),
#  ('almere', 9285.37),
#  ('venlo', 8676.56),
#  ('apeldoorn', 8630.11),
#  ('aalsmeer', 8131.75),
#  ('tilburg', 7948.19),
#  ('breda', 7652.17),
#  ('someren', 7361.21),
#  ('zoetermeer', 7139.79),
#  ('groningen', 7131.51),
#  ('ede', 6907.01),
#  ('amstelveen', 6850.06),
#  ("'s-hertogenbosch", 6826.37),
#  ('uithoorn', 6685.26),
#  ('brielle', 6621.81),
#  ('enschede', 6456.79),
#  ('heerhugowaard', 6229.21),
#  ('helden', 6053.02),
#  ('nijmegen', 6027.26),
#  ('kampen', 5924.23),
#  ('sittard-geleen', 5885.03),
#  ('zwolle', 5882.76),
#  ('delft', 5648.42),
#  ('etten-leur', 5628.01),
#  ('lelystad', 5610.64),
#  ('maastricht', 5538.14),
#  ('arnhem', 5455.45),
#  ('asten', 5328.31),
#  ('laarbeek', 5309.64),
#  ('roosendaal', 5298.08),
#  ('dordrecht', 5288.42),
#  ('zundert', 5232.28),
#  ('amersfoort', 5229.12),
#  ('vlaardingen', 5050.78),
#  ('hoogezand-sappemeer', 5050.14),
#  ('zaanstad', 4992.84),
#  ('horst aan de maas', 4725.15),
#  ('uden', 4645.97),
#  ('heusden', 4565.81),
#  ('oosterhout', 4350.64),
#  ('veghel', 4323.17),
#  ('heerlen', 4174.95),
#  ('steenwijkerland', 4080.59),
#  ('ridderkerk', 4077.81),
#  ('bergen op zoom', 4047.86),
#  ('deventer', 3978.56),
#  ('overbetuwe', 3974.84),
#  ('leidschendam-voorburg', 3966.79),
#  ('barneveld', 3844.83),
#  ('kessel', 3844.55),
#  ('oss', 3838.86),
#  ('velsen', 3817.79),
#  ('schiedam', 3742.72),
#  ('roermond', 3649.58),
#  ('helmond', 3637.63),
#  ('oirschot', 3500.42),
#  ('leeuwarden', 3387.49),
#  ('maassluis', 3384.52),
#  ('waalwijk', 3374.96),
#  ('oostflakkee', 3337.92),
#  ('borsele', 3308.82),
#  ('barendrecht', 3278.47),
#  ('hardenberg', 3256.95),
#  ('almelo', 3236.4),
#  ('coevorden', 3215.11),
#  ('woerden', 3184.48),
#  ('zeewolde', 3157.82),
#  ('alkemade', 3156.11),
#  ('delfzijl', 3151.3),
#  ('leiden', 3084.03),
#  ('spijkenisse', 3070.04),
#  ('nieuwegein', 3029.68),
#  ('kapelle', 3008.5),
#  ('dronten', 2983.63),
#  ('hengelo', 2927.37),
#  ('zwijndrecht', 2918.94),
#  ('alkmaar', 2907.73),
#  ('menterwolde', 2883.98),
#  ('heemskerk', 2865.23),
#  ('menaldumadeel', 2839.95),
#  ('venray', 2835.07),
#  ('hilversum', 2820.63),
#  ('houten', 2799.97),
#  ('de ronde venen', 2715.83),
#  ('lingewaard', 2711.97),
#  ('haarlem', 2603.09),
#  ('alphen aan den rijn', 2586.96),
#  ('assen', 2560.56),
#  ('weert', 2515.17),
#  ('hoogeveen', 2511.15),
#  ('drimmelen', 2510.12),
#  ('veldhoven', 2505.16),
#  ('nieuwerkerk aan den ijssel', 2504.9),
#  ('rijswijk', 2473.17),
#  ('echt-susteren', 2470.56),
#  ('hof van twente', 2461.47),
#  ('noorder-koggenland', 2456.36),
#  ('beverwijk', 2450.96),
#  ('woensdrecht', 2428.15),
#  ('heerenveen', 2390.61),
#  ('midden-drenthe', 2386.51),
#  ('maasdriel', 2385.68),
#  ('geldermalsen', 2382.44),
#  ('hulst', 2373.3),
#  ('halderberge', 2367.73),
#  ('vlissingen', 2367.25),
#  ('ouder-amstel', 2361.42),
#  ('rijnwoude', 2349.92),
#  ('noordwijk', 2310.61),
#  ('smallingerland', 2242.72),
#  ('wijchen', 2242.26),
#  ('sluis', 2231.09),
#  ('tiel', 2227.03),
#  ('boxmeer', 2201.32),
#  ('deurne', 2201.17),
#  ('hendrik-ido-ambacht', 2198.91),
#  ('albrandswaard', 2184.26),
#  ('eemsmond', 2183.37),
#  ('capelle aan den ijssel', 2181.19),
#  ('liemeer', 2110.96),
#  ('gemert-bakel', 2089.89),
#  ('gouda', 2087.31),
#  ('noordenveld', 2071.04),
#  ('doetinchem', 2067.13),
#  ('nederweert', 2066.73),
#  ('soest', 2059.55),
#  ('jacobswoude', 2059.21),
#  ('binnenmaas', 2049.37),
#  ('werkendam', 2042.63),
#  ('meijel', 2033.78),
#  ('wageningen', 2021.54),
#  ('zeist', 2021.39),
#  ('sevenum', 2016.42),
#  ('nijkerk', 2013.51),
#  ('slochteren', 2013.25),
#  ('epe', 2010.69),
#  ('buren', 2007.97),
#  ('schouwen-duiveland', 2000.15),
#  ('skarsterlân', 1970.26),
#  ('rijnsburg', 1957.09),
#  ('bernheze', 1944.15),
#  ('aa en hunze', 1932.35),
#  ('de bilt', 1932.07),
#  ('stein', 1930.84),
#  ('borger-odoorn', 1928.46),
#  ('ermelo', 1924.73),
#  ('hoorn', 1916.58),
#  ('oisterwijk', 1909.66),
#  ('veenendaal', 1890.57),
#  ('medemblik', 1883.27),
#  ('heeze-leende', 1860.81),
#  ('goes', 1856.45),
#  ('wassenaar', 1854.46),
#  ('bernisse', 1819.71),
#  ('raalte', 1817.25),
#  ('gilze en rijen', 1804.8),
#  ('beemster', 1763.48),
#  ('harderwijk', 1756.01),
#  ('boxtel', 1736.36),
#  ('sint-michielsgestel', 1727.73),
#  ('purmerend', 1714.2),
#  ('hellevoetsluis', 1690.89),
#  ('voorst', 1681.59),
#  ('kesteren', 1676.14),
#  ('opsterland', 1675.42),
#  ('rijssen', 1665.55),
#  ('weststellingwerf', 1662.33),
#  ('rucphen', 1661.06),
#  ('cuijk', 1645.77),
#  ('meppel', 1632.28),
#  ('best', 1630.24),
#  ('neerijnen', 1623.26),
#  ('valkenswaard', 1623.01),
#  ('eersel', 1608.64),
#  ('beuningen', 1608.24),
#  ('den helder', 1608.03),
#  ('bergeijk', 1594.41),
#  ('dalfsen', 1590.57),
#  ('vianen', 1584.46),
#  ('cranendonck', 1583.1),
#  ('nunspeet', 1579.11),
#  ('ter aar', 1570.03),
#  ('duiven', 1558.17),
#  ('ommen', 1551.76),
#  ('westerveld', 1522.3),
#  ('wierden', 1518.04),
#  ('veendam', 1514.94),
#  ('geertruidenberg', 1508.42),
#  ('zwartewaterland', 1491.17),
#  ('oldebroek', 1481.71),
#  ('tynaarlo', 1476.3),
#  ('kerkrade', 1465.23),
#  ('leusden', 1465.04),
#  ('wijdemeren', 1462.75),
#  ('boekel', 1460.78),
#  ('staphorst', 1459.88),
#  ('hellendoorn', 1459.64),
#  ('de wolden', 1453.58),
#  ('dinkelland', 1450.11),
#  ('voorschoten', 1446.25),
#  ('schijndel', 1443.26),
#  ('tytsjerksteradiel', 1436.19),
#  ('loon op zand', 1423.4),
#  ('gorinchem', 1412.89),
#  ('west maas en waal', 1406.66),
#  ('moordrecht', 1399.94),
#  ('hilvarenbeek', 1399.84),
#  ('vlagtwedde', 1396.52),
#  ('nuenen c.a.', 1396.25),
#  ('reeuwijk', 1392.41),
#  ('son en breugel', 1392.15),
#  ('sint-oedenrode', 1389.54),
#  ('winterswijk', 1361.4),
#  ('twenterand', 1355.12),
#  ('vught', 1347.25),
#  ('bodegraven', 1346.33),
#  ('putten', 1346.11),
#  ('alphen-chaam', 1324.08),
#  ('rheden', 1322.42),
#  ('wervershoof', 1316.46),
#  ('middelburg', 1311.82),
#  ('landerd', 1311.72),
#  ('tholen', 1308.65),
#  ('ooststellingwerf', 1293.26),
#  ('haelen', 1289.01),
#  ('bergen', 1285.98),
#  ('breukelen', 1265.68),
#  ('aalburg', 1259.12),
#  ('veere', 1255.05),
#  ('beek', 1250.89),
#  ('dongeradeel', 1249.88),
#  ('vlist', 1248.65),
#  ('rozenburg', 1237.7),
#  ('maarssen', 1235.07),
#  ('bergh', 1231.38),
#  ('landgraaf', 1229.48),
#  ('haaksbergen', 1228.98),
#  ('bladel', 1217.75),
#  ('diemen', 1216.59),
#  ('korendijk', 1205.46),
#  ('stadskanaal', 1204.97),
#  ('woudrichem', 1203.69),
#  ('heerde', 1199.96),
#  ('wûnseradiel', 1197.82),
#  ('lingewaal', 1191.65),
#  ('wester-koggenland', 1182.84),
#  ('baarle-nassau', 1179.41),
#  ('zutphen', 1178.44),
#  ('enkhuizen', 1173.49),
#  ('waalre', 1171.3),
#  ('lochem', 1164.27),
#  ('oud-beijerland', 1164.14),
#  ('renkum', 1162.19),
#  ('obdam', 1158.23),
#  ('elburg', 1158.19),
#  ('tubbergen', 1153.4),
#  ('haaren', 1152.25),
#  ('wymbritseradiel', 1144.68),
#  ('sint anthonis', 1141.48),
#  ('boarnsterhim', 1141.29),
#  ('katwijk', 1129.33),
#  ('bunschoten', 1126.62),
#  ('dongen', 1121.4),
#  ('lopik', 1121.3),
#  ('giessenlanden', 1109.54),
#  ('castricum', 1108.34),
#  ('gendringen', 1100.62),
#  ('cromstrijen', 1098.99),
#  ('leiderdorp', 1094.56),
#  ('schermer', 1093.87),
#  ('gennep', 1082.11),
#  ('zederik', 1079.29),
#  ('ouderkerk', 1075.63),
#  ('graafstroom', 1075.42),
#  ('boskoop', 1070.56),
#  ('lichtenvoorde', 1068.61),
#  ('bunnik', 1066.16),
#  ('valkenburg aan de geul', 1056.54),
#  ('zuidhorn', 1055.89),
#  ('brummen', 1049.91),
#  ('zevenaar', 1043.26),
#  ('eibergen', 1039.88),
#  ('olst-wijhe', 1039.66),
#  ('margraten', 1039.25),
#  ('reusel-de mierden', 1036.65),
#  ('valkenburg', 1035.23),
#  ('haarlemmerliede c.a.', 1034.04),
#  ('voorhout', 1032.49),
#  ('langedijk', 1027.48),
#  ('sneek', 1026.93),
#  ('strijen', 1020.83),
#  ('nederlek', 1019.47),
#  ('didam', 1016.51),
#  ('heumen', 1014.29),
#  ('goirle', 1014.21),
#  ('nuth', 1012.09),
#  ('opmeer', 1008.09),
#  ('haren', 1005.27),
#  ('losser', 1004.27),
#  ('scheemda', 1001.74),
#  ('brunssum', 991.79),
#  ('gulpen-wittem', 989.86),
#  ('ijsselstein', 988.4),
#  ('rhenen', 978.99),
#  ('wisch', 970.83),
#  ('papendrecht', 966.17),
#  ('geldrop', 964.91),
#  ('baarn', 963.44),
#  ('oegstgeest', 960.11),
#  ('culemborg', 959.75),
#  ('zoeterwoude', 959.39),
#  ('noordwijkerhout', 943.54),
#  ('krimpen aan den ijssel', 940.02),
#  ('meerssen', 936.9),
#  ('bergambacht', 933.92),
#  ('montfoort', 927.25),
#  ('roggel en neer', 926.74),
#  ('de marne', 924.34),
#  ('oldenzaal', 923.14),
#  ('bloemendaal', 921.7),
#  ('abcoude', 920.18),
#  ('middelharnis', 919.96),
#  ('achtkarspelen', 918.99),
#  ('zijpe', 915.21),
#  ('heythuysen', 908.35),
#  ('wormerland', 899.32),
#  ('huizen', 892.87),
#  ('niedorp', 889.07),
#  ('druten', 885.82),
#  ('anna paulowna', 884.71),
#  ('harenkarspel', 881.23),
#  ('lemsterland', 880.66),
#  ('reiderland', 878.54),
#  ('franekeradeel', 874.2),
#  ("'s-gravendeel", 873.46),
#  ('gorssel', 867.49),
#  ('andijk', 865.98),
#  ('groesbeek', 857.05),
#  ('nieuwkoop', 850.49),
#  ('naarden', 848.93),
#  ('sliedrecht', 838.17),
#  ('voerendaal', 836.06),
#  ('winschoten', 828.68),
#  ('het bildt', 826.44),
#  ('zandvoort', 821.34),
#  ('maasdonk', 820.71),
#  ('goedereede', 818.18),
#  ('venhuizen', 814.63),
#  ('maasbracht', 814.34),
#  ('borne', 803.62),
#  ('heiloo', 799.16),
#  ('waterland', 793.31),
#  ('wijk bij duurstede', 791.95),
#  ('weesp', 791.36),
#  ('texel', 788.69),
#  ('liesveld', 780.3),
#  ('wognum', 778.27),
#  ('beesel', 770.67),
#  ('hillegom', 765.28),
#  ('alblasserdam', 765.03),
#  ('aalten', 761.87),
#  ('laren', 751.12),
#  ('littenseradiel', 747.88),
#  ('lith', 745.19),
#  ('lisse', 741.73),
#  ('arcen en velden', 739.66),
#  ('eemnes', 739.3),
#  ('bellingwedde', 735.83),
#  ('stede broec', 730.34),
#  ('nijefurd', 730.2),
#  ('ambt montfort', 728.54),
#  ('leek', 720.05),
#  ('schinnen', 716.74),
#  ('oudewater', 711.66),
#  ('winsum', 705.08),
#  ('noord-beveland', 704.6),
#  ('mill en sint hubert', 684.63),
#  ('woudenberg', 680.03),
#  ('gaasterlân-sleat', 679.49),
#  ('leerdam', 678.98),
#  ('harlingen', 676.2),
#  ('eijsden', 672.63),
#  ('loppersum', 663.51),
#  ('kollumerland c.a.', 662.4),
#  ('uitgeest', 661.73),
#  ('driebergen-rijsenburg', 657.46),
#  ('mierlo', 657.42),
#  ('edam-volendam', 656.83),
#  ('zelhem', 655.31),
#  ('dantumadeel', 651.91),
#  ('simpelveld', 650.83),
#  ('drechterland', 636.81),
#  ('oostzaan', 619.25),
#  ('ubbergen', 618.77),
#  ('grootegast', 618.55),
#  ('roerdalen', 599.96),
#  ('landsmeer', 598.73),
#  ('sassenheim', 598.53),
#  ('loenen', 596.32),
#  ('bussum', 590.28),
#  ('grave', 584.77),
#  ('heemstede', 584.7),
#  ('heel', 583.62),
#  ('urk', 583.07),
#  ('appingedam', 575.31),
#  ('hardinxveld-giessendam', 568.47),
#  ('pekela', 567.93),
#  ('zeevang', 559.9),
#  ('hattem', 558.26),
#  ('meerlo-wanssum', 543.97),
#  ('ferwerderadiel', 529.47),
#  ('hunsel', 528.16),
#  ('rijnwaarden', 516.97),
#  ('dirksland', 513.23),
#  ('muiden', 512.22),
#  ('westervoort', 504.82),
#  ('schagen', 502.78),
#  ('warmond', 498.36),
#  ('borculo', 494.39),
#  ('blaricum', 489.12),
#  ('wehl', 488.06),
#  ('groenlo', 482.51),
#  ('ruurlo', 473.65),
#  ('vorden', 471.93),
#  ('marum', 464.29),
#  ('amerongen', 463.84),
#  ('maarn', 457.07),
#  ('swalmen', 454.57),
#  ('angerlo', 422.92),
#  ('bedum', 418.44),
#  ('leersum', 415.91),
#  ('renswoude', 413.81),
#  ('steenderen', 413.41),
#  ('onderbanken', 411.02),
#  ('hummelo en keppel', 391.01),
#  ('nieuw-lekkerland', 387.01),
#  ('ten boer', 382.72),
#  ('doorn', 372.74),
#  ('leeuwarderadeel', 364.43),
#  ('neede', 361.57),
#  ('scherpenzeel', 336.8),
#  ('terschelling', 322.93),
#  ('mook en middelaar', 319.34),
#  ('doesburg', 305.18),
#  ('wieringen', 304.93),
#  ('bathmen', 298.15),
#  ('ameland', 282.81),
#  ('graft-de rijp', 279.36),
#  ('schoonhoven', 257.83),
#  ('vaals', 250.59),
#  ('warnsveld', 247.41),
#  ('rozendaal', 213.58),
#  ('millingen aan de rijn', 200.09),
#  ('thorn', 193.94),
#  ('bolsward', 187.54),
#  ('dinxperlo', 167.54),
#  ('vlieland', 141.43),
#  ('schiermonnikoog', 124.04),
#  ('bennebroek', 84.68)]

# %%
sorted(city_gdp_dict.items(), key= lambda x: x[1], reverse=True)
# Out:
# [('noordoostpolder', (44.58822633368545, 0.04406)),
#  ('naaldwijk', (39.738347140873586, 0.039267)),
#  ('maasland', (39.66563690911648, 0.039195)),
#  ('rotterdam', (37.21825037028223, 0.036777)),
#  ('de lier', (30.327583609138316, 0.029968)),
#  ('schipluiden', (29.06531067848069, 0.028721)),
#  ('zevenhuizen-moerkapelle', (28.960863236516822, 0.028617)),
#  ('wieringermeer', (28.622541743978303, 0.028283)),
#  ('waddinxveen', (26.64020226712685, 0.026324)),
#  ("'s-gravenzande", (19.530626083693814, 0.019299)),
#  ('pijnacker-nootdorp', (19.358086315644645, 0.019129)),
#  ('berkel en rodenrijs', (18.492179991388564, 0.018273)),
#  ('reimerswaal', (17.10437408720899, 0.016902)),
#  ('haarlemmermeer', (16.378878234464697, 0.016185)),
#  ('emmen', (16.270978254533937, 0.016078)),
#  ('amsterdam', (15.634055793006658, 0.015449)),
#  ('monster', (15.534563886610425, 0.01535)),
#  ('bleiswijk', (14.755717064683655, 0.014581)),
#  ('maasbree', (11.275613250486083, 0.011142)),
#  ('steenbergen', (10.996023022889181, 0.010866)),
#  ('westvoorne', (9.926901620855961, 0.009809)),
#  ("'s-gravenhage", (9.542646125555962, 0.009429)),
#  ('wateringen', (9.535632136752549, 0.009423)),
#  ('bergschenhoek', (7.86027991985046, 0.007767)),
#  ('eindhoven', (7.453321536878544, 0.007365)),
#  ('terneuzen', (6.180685546676742, 0.006107)),
#  ('zaltbommel', (6.08144958552411, 0.006009)),
#  ('utrecht', (6.052446088344783, 0.005981)),
#  ('moerdijk', (5.303076534580181, 0.00524)),
#  ('almere', (5.056481460834115, 0.004997)),
#  ('venlo', (4.724945240072807, 0.004669)),
#  ('apeldoorn', (4.699650226103978, 0.004644)),
#  ('aalsmeer', (4.428261137589327, 0.004376)),
#  ('tilburg', (4.328300905853735, 0.004277)),
#  ('breda', (4.1670989675318255, 0.004118)),
#  ('someren', (4.0086525248112554, 0.003961)),
#  ('zoetermeer', (3.8880750868569374, 0.003842)),
#  ('groningen', (3.8835660940547436, 0.003838)),
#  ('ede', (3.7613113979083046, 0.003717)),
#  ('amstelveen', (3.73029845828452, 0.003686)),
#  ("'s-hertogenbosch", (3.717397728878243, 0.003673)),
#  ('uithoorn', (3.6405542537191162, 0.003597)),
#  ('brielle', (3.6060016458327397, 0.003563)),
#  ('enschede', (3.5161376371107558, 0.003474)),
#  ('heerhugowaard', (3.3922056827721967, 0.003352)),
#  ('helden', (3.2962588902820364, 0.003257)),
#  ('nijmegen', (3.2822309126752107, 0.003243)),
#  ('kampen', (3.2261244478913906, 0.003188)),
#  ('sittard-geleen', (3.2047775254462216, 0.003167)),
#  ('zwolle', (3.2035413643760555, 0.003166)),
#  ('delft', (3.0759281550444006, 0.003039)),
#  ('etten-leur', (3.0648135966998624, 0.003028)),
#  ('lelystad', (3.0553545139735214, 0.003019)),
#  ('maastricht', (3.015873598736921, 0.00298)),
#  ('arnhem', (2.9708435727932723, 0.002936)),
#  ('asten', (2.9016076615769775, 0.002867)),
#  ('laarbeek', (2.891440645198118, 0.002857)),
#  ('roosendaal', (2.885145481334185, 0.002851)),
#  ('dordrecht', (2.8798849897316257, 0.002846)),
#  ('zundert', (2.8493131472297946, 0.002816)),
#  ('amersfoort', (2.847592323889827, 0.002814)),
#  ('vlaardingen', (2.7504747180512705, 0.002718)),
#  ('hoogezand-sappemeer', (2.7501261968684925, 0.002718)),
#  ('zaanstad', (2.718922659722876, 0.002687)),
#  ('horst aan de maas', (2.5731482293823844, 0.002543)),
#  ('uden', (2.5300296243005365, 0.0025)),
#  ('heusden', (2.4863773461575587, 0.002457)),
#  ('oosterhout', (2.369203435378809, 0.002341)),
#  ('veghel', (2.354244252736748, 0.002326)),
#  ('heerlen', (2.2735289250626938, 0.002247)),
#  ('steenwijkerland', (2.222143833176823, 0.002196)),
#  ('ridderkerk', (2.2206299442891297, 0.002194)),
#  ('bergen op zoom', (2.2043202420638033, 0.002178)),
#  ('deventer', (2.166581932741094, 0.002141)),
#  ('overbetuwe', (2.1645561533661954, 0.002139)),
#  ('leidschendam-voorburg', (2.1601724103640625, 0.002135)),
#  ('barneveld', (2.0937573424708793, 0.002069)),
#  ('kessel', (2.0936048644534138, 0.002069)),
#  ('oss', (2.090506293312776, 0.002066)),
#  ('velsen', (2.0790323224984975, 0.002054)),
#  ('schiedam', (2.038151876887303, 0.002014)),
#  ('roermond', (1.987431153506103, 0.001964)),
#  ('helmond', (1.9809236095464156, 0.001957)),
#  ('oirschot', (1.9062039353448437, 0.001884)),
#  ('leeuwarden', (1.8447062835149222, 0.001823)),
#  ('maassluis', (1.8430889274010918, 0.001821)),
#  ('waalwijk', (1.8378828922333417, 0.001816)),
#  ('oostflakkee', (1.8177122287800493, 0.001796)),
#  ('borsele', (1.8018654062506, 0.00178)),
#  ('barendrecht', (1.7853378782860367, 0.001764)),
#  ('hardenberg', (1.7736188535151176, 0.001753)),
#  ('almelo', (1.7624280561618468, 0.001742)),
#  ('coevorden', (1.7508342811909885, 0.00173)),
#  ('woerden', (1.73415427520896, 0.001714)),
#  ('zeewolde', (1.7196361896888528, 0.001699)),
#  ('alkemade', (1.718704984653617, 0.001698)),
#  ('delfzijl', (1.7160856301392993, 0.001696)),
#  ('leiden', (1.679452786443215, 0.00166)),
#  ('spijkenisse', (1.671834331213421, 0.001652)),
#  ('nieuwegein', (1.6498557141244665, 0.00163)),
#  ('kapelle', (1.6383218412318983, 0.001619)),
#  ('dronten', (1.6247785258948741, 0.001606)),
#  ('hengelo', (1.5941413356712721, 0.001575)),
#  ('zwijndrecht', (1.5895506582168648, 0.001571)),
#  ('alkmaar', (1.5834460918747642, 0.001565)),
#  ('menterwolde', (1.570512688607602, 0.001552)),
#  ('heemskerk', (1.560302107080895, 0.001542)),
#  ('menaldumadeel', (1.5465355203611533, 0.001528)),
#  ('venray', (1.543878046342469, 0.001526)),
#  ('hilversum', (1.5360145371560345, 0.001518)),
#  ('houten', (1.5247638377244734, 0.001507)),
#  ('de ronde venen', (1.4789441934760932, 0.001461)),
#  ('lingewaard', (1.4768421750924616, 0.001459)),
#  ('haarlem', (1.4175500088723094, 0.001401)),
#  ('alphen aan den rijn', (1.4087661859376008, 0.001392)),
#  ('assen', (1.3943896871479973, 0.001378)),
#  ('weert', (1.369671911388145, 0.001353)),
#  ('hoogeveen', (1.367482762708819, 0.001351)),
#  ('drimmelen', (1.3669218614302852, 0.001351)),
#  ('veldhoven', (1.3642208222637535, 0.001348)),
#  ('nieuwerkerk aan den ijssel', (1.36407923553325, 0.001348)),
#  ('rijswijk', (1.346800208768321, 0.001331)),
#  ('echt-susteren', (1.3453788958198034, 0.001329)),
#  ('hof van twente', (1.3404288058956557, 0.001325)),
#  ('noorder-koggenland', (1.337646082076911, 0.001322)),
#  ('beverwijk', (1.3347054345972191, 0.001319)),
#  ('woensdrecht', (1.3222839218172626, 0.001307)),
#  ('heerenveen', (1.301840976189925, 0.001286)),
#  ('midden-drenthe', (1.2996082623627516, 0.001284)),
#  ('maasdriel', (1.2991562739538358, 0.001284)),
#  ('geldermalsen', (1.297391885466021, 0.001282)),
#  ('hulst', (1.292414567324469, 0.001277)),
#  ('halderberge', (1.2893813439056017, 0.001274)),
#  ('vlissingen', (1.289119953018518, 0.001274)),
#  ('ouder-amstel', (1.2859451428691473, 0.001271)),
#  ('rijnwoude', (1.2796826528661003, 0.001265)),
#  ('noordwijk', (1.2582758283426416, 0.001243)),
#  ('smallingerland', (1.2213053547507404, 0.001207)),
#  ('wijchen', (1.2210548551506188, 0.001207)),
#  ('sluis', (1.214972071382442, 0.001201)),
#  ('tiel', (1.2127611401291924, 0.001198)),
#  ('boxmeer', (1.1987603907397715, 0.001185)),
#  ('deurne', (1.1986787060875579, 0.001184)),
#  ('hendrik-ido-ambacht', (1.197447990660872, 0.001183)),
#  ('albrandswaard', (1.1894701229613385, 0.001175)),
#  ('eemsmond', (1.1889854606915373, 0.001175)),
#  ('capelle aan den ijssel', (1.1877983104126988, 0.001174)),
#  ('liemeer', (1.149553556246265, 0.001136)),
#  ('gemert-bakel', (1.1380795854319867, 0.001125)),
#  ('gouda', (1.1366746094139117, 0.001123)),
#  ('noordenveld', (1.1278145474704706, 0.001114)),
#  ('doetinchem', (1.1256853008694347, 0.001112)),
#  ('nederweert', (1.1254674751301983, 0.001112)),
#  ('soest', (1.1215575031109049, 0.001108)),
#  ('jacobswoude', (1.1213723512325537, 0.001108)),
#  ('binnenmaas', (1.1160138380473377, 0.001103)),
#  ('werkendam', (1.1123434743412042, 0.001099)),
#  ('meijel', (1.1075240798605983, 0.001094)),
#  ('wageningen', (1.1008586122399642, 0.001088)),
#  ('zeist', (1.1007769275877506, 0.001088)),
#  ('sevenum', (1.0980704427777381, 0.001085)),
#  ('nijkerk', (1.096485760524793, 0.001083)),
#  ('slochteren', (1.0963441737942894, 0.001083)),
#  ('epe', (1.0949500890631763, 0.001082)),
#  ('buren', (1.0934688740363687, 0.001081)),
#  ('schouwen-duiveland', (1.0892103808342968, 0.001076)),
#  ('skarsterlân', (1.0729333524698554, 0.00106)),
#  ('rijnsburg', (1.0657614400054964, 0.001053)),
#  ('bernheze', (1.0587147773411985, 0.001046)),
#  ('aa en hunze', (1.052288918033724, 0.00104)),
#  ('de bilt', (1.0521364400162587, 0.00104)),
#  ('stein', (1.0514666258681067, 0.001039)),
#  ('borger-odoorn', (1.05017056271965, 0.001038)),
#  ('ermelo', (1.0481393377012704, 0.001036)),
#  ('hoorn', (1.0437011382643282, 0.001031)),
#  ('oisterwijk', (1.0399327529755384, 0.001028)),
#  ('veenendaal', (1.0295370195704805, 0.001017)),
#  ('medemblik', (1.0255616998294157, 0.001013)),
#  ('heeze-leende', (1.0133307845712909, 0.001001)),
#  ('goes', (1.010956484013614, 0.000999)),
#  ('wassenaar', (1.0098728009609128, 0.000998)),
#  ('bernisse', (0.9909491898647492, 0.000979)),
#  ('raalte', (0.9896095615684453, 0.000978)),
#  ('gilze en rijen', (0.9828297354347116, 0.000971)),
#  ('beemster', (0.9603283365715899, 0.000949)),
#  ('harderwijk', (0.9562604408913498, 0.000945)),
#  ('boxtel', (0.9455597514513608, 0.000934)),
#  ('sint-michielsgestel', (0.9408601611273352, 0.00093)),
#  ('purmerend', (0.9334922054976634, 0.000922)),
#  ('hellevoetsluis', (0.9207984105436613, 0.00091)),
#  ('voorst', (0.9157339621064144, 0.000905)),
#  ('kesteren', (0.9127660864093183, 0.000902)),
#  ('opsterland', (0.9123740000786927, 0.000902)),
#  ('rijssen', (0.9069991499630342, 0.000896)),
#  ('weststellingwerf', (0.9052456527621809, 0.000895)),
#  ('rucphen', (0.9045540560401054, 0.000894)),
#  ('cuijk', (0.8962276671577935, 0.000886)),
#  ('meppel', (0.8888814941020452, 0.000878)),
#  ('best', (0.8877705828319395, 0.000877)),
#  ('neerijnen', (0.883969523682264, 0.000873)),
#  ('valkenswaard', (0.8838333825952412, 0.000873)),
#  ('eersel', (0.8760079929131731, 0.000866)),
#  ('beuningen', (0.8757901671739367, 0.000865)),
#  ('den helder', (0.8756758086608375, 0.000865)),
#  ('bergeijk', (0.8682588422398375, 0.000858)),
#  ('dalfsen', (0.8661677151431678, 0.000856)),
#  ('vianen', (0.8628404269763317, 0.000853)),
#  ('cranendonck', (0.8620998194629278, 0.000852)),
#  ('nunspeet', (0.8599270077140446, 0.00085)),
#  ('ter aar', (0.854982363433378, 0.000845)),
#  ('duiven', (0.8485238302650182, 0.000838)),
#  ('ommen', (0.8450331727937546, 0.000835)),
#  ('westerveld', (0.8289903070989925, 0.000819)),
#  ('wierden', (0.8266704629761246, 0.000817)),
#  ('veendam', (0.8249823134970424, 0.000815)),
#  ('geertruidenberg', (0.8214317539474889, 0.000812)),
#  ('zwartewaterland', (0.8120380189429185, 0.000802)),
#  ('oldebroek', (0.8068864402099771, 0.000797)),
#  ('tynaarlo', (0.8039403470868046, 0.000794)),
#  ('kerkrade', (0.7979120197534367, 0.000788)),
#  ('leusden', (0.7978085525272994, 0.000788)),
#  ('wijdemeren', (0.796561500170171, 0.000787)),
#  ('boekel', (0.7954887084044316, 0.000786)),
#  ('staphorst', (0.7949986004911498, 0.000786)),
#  ('hellendoorn', (0.794867905047608, 0.000785)),
#  ('de wolden', (0.791567845098176, 0.000782)),
#  ('dinkelland', (0.7896782068103002, 0.00078)),
#  ('voorschoten', (0.7875761884266688, 0.000778)),
#  ('schijndel', (0.7859479410258766, 0.000777)),
#  ('tytsjerksteradiel', (0.7820978710848729, 0.000773)),
#  ('loon op zand', (0.7751328930727885, 0.000766)),
#  ('gorinchem', (0.7694095217743517, 0.00076)),
#  ('west maas en waal', (0.7660168858857445, 0.000757)),
#  ('moordrecht', (0.7623574134665727, 0.000753)),
#  ('hilvarenbeek', (0.7623029570317635, 0.000753)),
#  ('vlagtwedde', (0.7604950033961013, 0.000751)),
#  ('nuenen c.a.', (0.7603479710221167, 0.000751)),
#  ('reeuwijk', (0.7582568439254471, 0.000749)),
#  ('son en breugel', (0.7581152571949434, 0.000749)),
#  ('sint-oedenrode', (0.7566939442464258, 0.000748)),
#  ('winterswijk', (0.741369903491144, 0.000733)),
#  ('twenterand', (0.7379500393851322, 0.000729)),
#  ('vught', (0.7336643179656557, 0.000725)),
#  ('bodegraven', (0.7331633187654119, 0.000724)),
#  ('putten', (0.7330435146088318, 0.000724)),
#  ('alphen-chaam', (0.7210467620203862, 0.000712)),
#  ('rheden', (0.7201427852025553, 0.000712)),
#  ('wervershoof', (0.7168971816879326, 0.000708)),
#  ('middelburg', (0.7143704031127901, 0.000706)),
#  ('landerd', (0.714315946677981, 0.000706)),
#  ('tholen', (0.7126441341293415, 0.000704)),
#  ('ooststellingwerf', (0.7042632888122203, 0.000696)),
#  ('haelen', (0.7019488903328335, 0.000694)),
#  ('bergen', (0.7002988603581176, 0.000692)),
#  ('breukelen', (0.6892442040918695, 0.000681)),
#  ('aalburg', (0.6856718619683921, 0.000678)),
#  ('veere', (0.6834554850716617, 0.000675)),
#  ('beek', (0.681190097383603, 0.000673)),
#  ('dongeradeel', (0.680640087392031, 0.000673)),
#  ('vlist', (0.679970273243879, 0.000672)),
#  ('rozenburg', (0.6740072936322821, 0.000666)),
#  ('maarssen', (0.6725750893968027, 0.000665)),
#  ('bergh', (0.6705656469523468, 0.000663)),
#  ('landgraaf', (0.6695309746909738, 0.000662)),
#  ('haaksbergen', (0.6692586925169283, 0.000661)),
#  ('bladel', (0.6631432348878658, 0.000655)),
#  ('diemen', (0.6625115402440801, 0.000655)),
#  ('korendijk', (0.656450539049827, 0.000649)),
#  ('stadskanaal', (0.6561837025192623, 0.000648)),
#  ('woudrichem', (0.6554866601537057, 0.000648)),
#  ('heerde', (0.6534554351353262, 0.000646)),
#  ('wûnseradiel', (0.6522900674304113, 0.000645)),
#  ('lingewaal', (0.6489301054026897, 0.000641)),
#  ('wester-koggenland', (0.6441324934960075, 0.000636)),
#  ('baarle-nassau', (0.6422646377820553, 0.000635)),
#  ('zutphen', (0.6417364103644071, 0.000634)),
#  ('enkhuizen', (0.6390408168413563, 0.000631)),
#  ('waalre', (0.6378482209190369, 0.00063)),
#  ('lochem', (0.6340199335519568, 0.000627)),
#  ('oud-beijerland', (0.6339491401867051, 0.000626)),
#  ('renkum', (0.6328872397079276, 0.000625)),
#  ('obdam', (0.630730764889487, 0.000623)),
#  ('elburg', (0.6307089823155635, 0.000623)),
#  ('tubbergen', (0.6281005190882074, 0.000621)),
#  ('haaren', (0.6274742700879026, 0.00062)),
#  ('wymbritseradiel', (0.6233519179728534, 0.000616)),
#  ('sint anthonis', (0.6216093120589621, 0.000614)),
#  ('boarnsterhim', (0.6215058448328247, 0.000614)),
#  ('katwijk', (0.6149928552296559, 0.000608)),
#  ('bunschoten', (0.6135170858463291, 0.000606)),
#  ('dongen', (0.6106744599492939, 0.000603)),
#  ('lopik', (0.6106200035144849, 0.000603)),
#  ('giessenlanden', (0.6042159267809343, 0.000597)),
#  ('castricum', (0.6035624495632249, 0.000596)),
#  ('gendringen', (0.599358412795962, 0.000592)),
#  ('cromstrijen', (0.5984707729085738, 0.000591)),
#  ('leiderdorp', (0.5960583528465303, 0.000589)),
#  ('schermer', (0.5956826034463475, 0.000589)),
#  ('gennep', (0.5892785267127969, 0.000582)),
#  ('zederik', (0.5877428552511802, 0.000581)),
#  ('ouderkerk', (0.5857497497371671, 0.000579)),
#  ('graafstroom', (0.5856353912240679, 0.000579)),
#  ('boskoop', (0.5829888084923454, 0.000576)),
#  ('lichtenvoorde', (0.5819269080135678, 0.000575)),
#  ('bunnik', (0.5805927253607448, 0.000574)),
#  ('valkenburg aan de geul', (0.575354016332109, 0.000569)),
#  ('zuidhorn', (0.5750000495058499, 0.000568)),
#  ('brummen', (0.5717435547042655, 0.000565)),
#  ('zevenaar', (0.5681222017894599, 0.000561)),
#  ('eibergen', (0.5662815742929124, 0.00056)),
#  ('olst-wijhe', (0.5661617701363323, 0.000559)),
#  ('margraten', (0.5659384987536149, 0.000559)),
#  ('reusel-de mierden', (0.5645226314485783, 0.000558)),
#  ('valkenburg', (0.563749350074289, 0.000557)),
#  ('haarlemmerliede c.a.', (0.5631013185000605, 0.000556)),
#  ('voorhout', (0.5622572437605196, 0.000556)),
#  ('langedijk', (0.5595289763765834, 0.000553)),
#  ('sneek', (0.5592294659851333, 0.000553)),
#  ('strijen', (0.5559076234617779, 0.000549)),
#  ('nederlek', (0.5551670159483741, 0.000549)),
#  ('didam', (0.5535551054780247, 0.000547)),
#  ('heumen', (0.5523461726252624, 0.000546)),
#  ('goirle', (0.5523026074774153, 0.000546)),
#  ('nuth', (0.5511481310594621, 0.000545)),
#  ('opmeer', (0.548969873667098, 0.000542)),
#  ('haren', (0.5474342022054813, 0.000541)),
#  ('losser', (0.5468896378573903, 0.00054)),
#  ('scheemda', (0.54551189005672, 0.000539)),
#  ('brunssum', (0.540093474793214, 0.000534)),
#  ('gulpen-wittem', (0.5390424656013983, 0.000533)),
#  ('ijsselstein', (0.5382474016531854, 0.000532)),
#  ('rhenen', (0.5331230511376487, 0.000527)),
#  ('wisch', (0.5286794060572259, 0.000522)),
#  ('papendrecht', (0.5261417361951215, 0.00052)),
#  ('geldrop', (0.5254555851165268, 0.000519)),
#  ('baarn', (0.524655075524833, 0.000518)),
#  ('oegstgeest', (0.5228416762456899, 0.000517)),
#  ('culemborg', (0.5226456330803771, 0.000516)),
#  ('zoeterwoude', (0.5224495899150643, 0.000516)),
#  ('noordwijkerhout', (0.5138182449978212, 0.000508)),
#  ('krimpen aan den ijssel', (0.5119013784925409, 0.000506)),
#  ('meerssen', (0.5102023377264968, 0.000504)),
#  ('bergambacht', (0.5085795359691855, 0.000503)),
#  ('montfoort', (0.5049472917674181, 0.000499)),
#  ('roggel en neer', (0.5046695639498918, 0.000499)),
#  ('de marne', (0.5033626095144733, 0.000497)),
#  ('oldenzaal', (0.5027091322967641, 0.000497)),
#  ('bloemendaal', (0.5019249596355131, 0.000496)),
#  ('abcoude', (0.5010972218264146, 0.000495)),
#  ('middelharnis', (0.5009774176698346, 0.000495)),
#  ('achtkarspelen', (0.5004491902521863, 0.000495)),
#  ('zijpe', (0.4983907370164021, 0.000492)),
#  ('heythuysen', (0.49465502558849755, 0.000489)),
#  ('wormerland', (0.4897376095252355, 0.000484)),
#  ('huizen', (0.48622516948004824, 0.00048)),
#  ('niedorp', (0.4841558249573023, 0.000478)),
#  ('druten', (0.4823859908260064, 0.000477)),
#  ('anna paulowna', (0.4817815243996254, 0.000476)),
#  ('harenkarspel', (0.4798864404682685, 0.000474)),
#  ('lemsterland', (0.4795760387898566, 0.000474)),
#  ('reiderland', (0.4784215623719036, 0.000473)),
#  ('franekeradeel', (0.4760581531011885, 0.00047)),
#  ("'s-gravendeel", (0.47565517548360114, 0.00047)),
#  ('gorssel', (0.4724041263254976, 0.000467)),
#  ('andijk', (0.4715818341598802, 0.000466)),
#  ('groesbeek', (0.46671887453142713, 0.000461)),
#  ('nieuwkoop', (0.4631465324079499, 0.000458)),
#  ('naarden', (0.46229701202492784, 0.000457)),
#  ('sliedrecht', (0.4564374996394682, 0.000451)),
#  ('voerendaal', (0.45528846886499613, 0.00045)),
#  ('winschoten', (0.45126958397608424, 0.000446)),
#  ('het bildt', (0.45004975983636036, 0.000445)),
#  ('zandvoort', (0.44727248166109607, 0.000442)),
#  ('maasdonk', (0.44692940612179866, 0.000442)),
#  ('goedereede', (0.44555165832112836, 0.00044)),
#  ('venhuizen', (0.44361845488540513, 0.000438)),
#  ('maasbracht', (0.4434605312244588, 0.000438)),
#  ('borne', (0.43762280141292276, 0.000432)),
#  ('heiloo', (0.4351940444204367, 0.00043)),
#  ('waterland', (0.4320083429841041, 0.000427)),
#  ('wijk bij duurstede', (0.43126773547070035, 0.000426)),
#  ('weesp', (0.4309464425053266, 0.000426)),
#  ('texel', (0.4294924556959236, 0.000424)),
#  ('liesveld', (0.42492356081543964, 0.00042)),
#  ('wognum', (0.4238180951888149, 0.000419)),
#  ('beesel', (0.41967940614332294, 0.000415)),
#  ('hillegom', (0.41674420430711223, 0.000412)),
#  ('alblasserdam', (0.4166080632200895, 0.000412)),
#  ('aalten', (0.4148872398801218, 0.00041)),
#  ('laren', (0.40903317313814314, 0.000404)),
#  ('littenseradiel', (0.4072687846503281, 0.000402)),
#  ('lith', (0.40580390655396326, 0.000401)),
#  ('lisse', (0.4039197139095682, 0.000399)),
#  ('arcen en velden', (0.4027924657090198, 0.000398)),
#  ('eemnes', (0.402596422543707, 0.000398)),
#  ('bellingwedde', (0.4007067842558311, 0.000396)),
#  ('stede broec', (0.3977171259848113, 0.000393)),
#  ('nijefurd', (0.3976408869760786, 0.000393)),
#  ('ambt montfort', (0.3967369101582474, 0.000392)),
#  ('leek', (0.39211355884295446, 0.000387)),
#  ('schinnen', (0.3903110508507731, 0.000386)),
#  ('oudewater', (0.3875446639624706, 0.000383)),
#  ('winsum', (0.3839614305520316, 0.000379)),
#  ('noord-beveland', (0.38370003966494787, 0.000379)),
#  ('mill en sint hubert', (0.37282508963356975, 0.000368)),
#  ('woudenberg', (0.37032009363235097, 0.000366)),
#  ('gaasterlân-sleat', (0.3700260288843818, 0.000366)),
#  ('leerdam', (0.36974830106685536, 0.000365)),
#  ('harlingen', (0.3682344121791623, 0.000364)),
#  ('eijsden', (0.3662903174564772, 0.000362)),
#  ('loppersum', (0.3613238906018869, 0.000357)),
#  ('kollumerland c.a.', (0.3607194241755059, 0.000356)),
#  ('uitgeest', (0.36035456606228494, 0.000356)),
#  ('driebergen-rijsenburg', (0.35802927629593617, 0.000354)),
#  ('mierlo', (0.35800749372201246, 0.000354)),
#  ('edam-volendam', (0.3576862007566388, 0.000353)),
#  ('zelhem', (0.35685846294754037, 0.000353)),
#  ('dantumadeel', (0.35500694416403084, 0.000351)),
#  ('simpelveld', (0.35441881466809255, 0.00035)),
#  ('drechterland', (0.3467840225078561, 0.000343)),
#  ('oostzaan', (0.33722147255537743, 0.000333)),
#  ('ubbergen', (0.3369600816682938, 0.000333)),
#  ('grootegast', (0.3368402775117137, 0.000333)),
#  ('roerdalen', (0.3267168262807013, 0.000323)),
#  ('landsmeer', (0.3260470121325493, 0.000322)),
#  ('sassenheim', (0.32593809926293105, 0.000322)),
#  ('loenen', (0.32473461205364995, 0.000321)),
#  ('bussum', (0.32144544339118, 0.000318)),
#  ('grave', (0.31844489383319835, 0.000315)),
#  ('heemstede', (0.318406774328832, 0.000315)),
#  ('heel', (0.3178186448328937, 0.000314)),
#  ('urk', (0.3175191344414436, 0.000314)),
#  ('appingedam', (0.3132933151002571, 0.00031)),
#  ('hardinxveld-giessendam', (0.3095684949593144, 0.000306)),
#  ('pekela', (0.30927443021134515, 0.000306)),
#  ('zeevang', (0.30490157849617416, 0.000301)),
#  ('hattem', (0.3040084929653048, 0.0003)),
#  ('meerlo-wanssum', (0.29622666843108386, 0.000293)),
#  ('ferwerderadiel', (0.28833048538376377, 0.000285)),
#  ('hunsel', (0.2876171060877645, 0.000284)),
#  ('rijnwaarden', (0.2815234310326257, 0.000278)),
#  ('dirksland', (0.27948676037076525, 0.000276)),
#  ('muiden', (0.2789367503791933, 0.000276)),
#  ('westervoort', (0.2749069742033196, 0.000272)),
#  ('schagen', (0.27379606293321385, 0.000271)),
#  ('warmond', (0.27138908851465143, 0.000268)),
#  ('borculo', (0.26922716805273, 0.000266)),
#  ('blaricum', (0.26635731393829026, 0.000263)),
#  ('wehl', (0.2657800757293137, 0.000263)),
#  ('groenlo', (0.26275774359740844, 0.00026)),
#  ('ruurlo', (0.2579329034733218, 0.000255)),
#  ('vorden', (0.2569962527946052, 0.000254)),
#  ('marum', (0.2528357811751897, 0.00025)),
#  ('amerongen', (0.2525907272185487, 0.00025)),
#  ('maarn', (0.24890402658197236, 0.000246)),
#  ('swalmen', (0.24754261571174474, 0.000245)),
#  ('angerlo', (0.2303071540946633, 0.000228)),
#  ('bedum', (0.2278675058152154, 0.000225)),
#  ('leersum', (0.22648975801454507, 0.000224)),
#  ('renswoude', (0.22534617288355388, 0.000223)),
#  ('steenderen', (0.22512834714431748, 0.000222)),
#  ('onderbanken', (0.22382683835237988, 0.000221)),
#  ('hummelo en keppel', (0.21293010574707813, 0.00021)),
#  ('nieuw-lekkerland', (0.21075184835471397, 0.000208)),
#  ('ten boer', (0.20841566730140343, 0.000206)),
#  ('doorn', (0.20298091510745483, 0.000201)),
#  ('leeuwarderadeel', (0.19845558537481828, 0.000196)),
#  ('neede', (0.19689813133927786, 0.000195)),
#  ('scherpenzeel', (0.1834092724370628, 0.000181)),
#  ('terschelling', (0.17585616492904002, 0.000174)),
#  ('mook en middelaar', (0.1739011789193932, 0.000172)),
#  ('doesburg', (0.16619014775042404, 0.000164)),
#  ('wieringen', (0.16605400666340128, 0.000164)),
#  ('bathmen', (0.16236186038334402, 0.00016)),
#  ('ameland', (0.15400824328362744, 0.000152)),
#  ('graft-de rijp', (0.15212949628271336, 0.00015)),
#  ('schoonhoven', (0.14040502586831324, 0.000139)),
#  ('vaals', (0.1364623799881341, 0.000135)),
#  ('warnsveld', (0.13473066536120457, 0.000133)),
#  ('rozendaal', (0.11630805346528465, 0.000115)),
#  ('millingen aan de rijn', (0.1089618804095365, 0.000108)),
#  ('thorn', (0.10561280966877659, 0.000104)),
#  ('bolsward', (0.10212759784099393, 0.000101)),
#  ('dinxperlo', (0.09123631087917308, 9e-05)),
#  ('vlieland', (0.077017735750516, 7.6e-05)),
#  ('schiermonnikoog', (0.06754776173721279, 6.7e-05)),
#  ('bennebroek', (0.046113708996349395, 4.6e-05))]

# %%
209-14
# Out:
# 67
